# %%
import pandas as pd
import numpy as np
import os
import csv
import pylab as pl
from __future__ import print_function
import matplotlib.pyplot as plt

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
os.environ["PUIDATA"] = "%s/PUIdata"%os.getenv("HOME")

print("PUIdata", os.getenv("PUIDATA"))
# Out:
# PUIdata /nfshome/jl9489/PUIdata

# %%
# Moving .csv file into environmental variable.  For reproducibility purposes

# !mv 'JC-201801-citibike-tripdata.csv' $PUIDATA
# Out:
# mv: cannot stat 'JC-201801-citibike-tripdata.csv': No such file or directory

# %%
# Assign a local variable in notebook to hold data frame.  Then show first 7 rows.

citibike_data = pd.read_csv(os.getenv('PUIDATA'))

citibike_data.head(7)
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0           932   06:17.5  21:50.0              3183     Exchange Place
# 1           550   06:18.0  15:28.4              3183     Exchange Place
# 2           510   06:57.0  15:27.8              3183     Exchange Place
# 3           354   53:10.2  59:05.1              3183     Exchange Place
# 4           250   34:30.2  38:41.0              3183     Exchange Place
# 5           613   05:05.9  15:19.4              3183     Exchange Place
# 6           290   13:51.8  18:42.1              3183     Exchange Place
#
#    start station latitude  start station longitude  end station id  \
# 0               40.716247               -74.033459            3199
# 1               40.716247               -74.033459            3199
# 2               40.716247               -74.033459            3199
# 3               40.716247               -74.033459            3267
# 4               40.716247               -74.033459            3639
# 5               40.716247               -74.033459            3203
# 6               40.716247               -74.033459            3267
#
#   end station name  end station latitude  end station longitude  bikeid  \
# 0     Newport Pkwy             40.728745             -74.032108   31929
# 1     Newport Pkwy             40.728745             -74.032108   31845
# 2     Newport Pkwy             40.728745             -74.032108   31708
# 3     Morris Canal             40.712419             -74.038526   31697
# 4       Harborside             40.719252             -74.034234   31861
# 5    Hamilton Park             40.727596             -74.044247   31859
# 6     Morris Canal             40.712419             -74.038526   31694
#
#      usertype  birth year  gender
# 0  Subscriber        1992       1
# 1  Subscriber        1969       2
# 2  Subscriber        1946       1
# 3  Subscriber        1994       1
# 4  Subscriber        1991       1
# 5  Subscriber        1982       1
# 6  Subscriber        1958       1

# %%
# Null Hypothesis Test

# Idea: Citibike users born after 1980 have longer bike trips than users born before 1980.

# Null Hypothesis: During the month of Jan 2018, the avg trip duration for users born after 1980 was the same 
#                    or less than the trip duration for users born before 1980
#
#                 H0: 
#
#
# Alternative Hypothesis: During the month of Jan 2018, the avg trip duration for users born after 1980 was higher
#                          than the trip duration for users born before 1980
#
#                Ha:

# %%
# Cleaning the data
#
# First, remove ages that are not representative. (In the dataset, anyone born before 1931)

print(len(citibike_data))

citibike_data = citibike_data[citibike_data['birth year'] >= 1931]

print(len(citibike_data))
# Out:
# 12677
# 12666

# %%
# Next, isolate only columns needed for analysis


citibike_data.drop(['start station id','start station name','start station latitude','start station longitude',
                    'end station id','end station name','end station latitude','end station longitude',
                   'bikeid','usertype','gender'],axis=1, inplace=True)

citibike_data.head(7)
# Out:
#    tripduration starttime stoptime  birth year
# 0           932   06:17.5  21:50.0        1992
# 1           550   06:18.0  15:28.4        1969
# 2           510   06:57.0  15:27.8        1946
# 3           354   53:10.2  59:05.1        1994
# 4           250   34:30.2  38:41.0        1991
# 5           613   05:05.9  15:19.4        1982
# 6           290   13:51.8  18:42.1        1958

# %%
# Assign values to each age group, in order to plot.  Similar to the gender demarcation.
#


age_group = []

for i in citibike_data['birth year']:
    if i <= 1980:
        age_group.append('before_1980')
    else:
        age_group.append('after_1980')
    
    
citibike_data['before_after_1980'] = age_group    

citibike_data.head(7)
# Out:
#    tripduration starttime stoptime  birth year before_after_1980
# 0           932   06:17.5  21:50.0        1992        after_1980
# 1           550   06:18.0  15:28.4        1969       before_1980
# 2           510   06:57.0  15:27.8        1946       before_1980
# 3           354   53:10.2  59:05.1        1994        after_1980
# 4           250   34:30.2  38:41.0        1991        after_1980
# 5           613   05:05.9  15:19.4        1982        after_1980
# 6           290   13:51.8  18:42.1        1958       before_1980

# %%
# Find the average of each age group

before_age = citibike_data.loc[(citibike_data["birth year"] < 1980)]
after_age = citibike_data.loc[(citibike_data["birth year"] >= 1980)]



print("The mean trip time (in seconds) for users born before 1980 is: %i seconds" %(before_age['tripduration'].mean()))
print("The mean trip time (in seconds) for users born in 1980 and after is: %i seconds" %(after_age['tripduration'].mean()))
# Out:
# The mean trip time (in seconds) for users born before 1980 is: 540 seconds
# The mean trip time (in seconds) for users born in 1980 and after is: 528 seconds

# %%
# Graph avg trip duration for both age groups, born before and after 1980


n_bars = 1
width = 0.01

index = np.arange(n_bars)

p1 = plt.bar(index, before_age['tripduration'].mean(), width, color ='b')
p2 = plt.bar(index + width, after_age['tripduration'].mean(), width, color = 'r')

plt.ylabel('Trip Duration')
plt.xlabel('Age Group')
plt.title('Avg trip duration by Age Group')
plt.yticks(np.arange(0, 1000, 100))
plt.xticks(index)
plt.legend((p1[0], p2[0]), ('Born Before 1980', 'Born After 1980'))

plt.show()
